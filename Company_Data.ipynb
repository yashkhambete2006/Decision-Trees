# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import os

# %%
for dirname, _, filenames in os.walk('Company_Data.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data = 'Company_Data.csv'

# %%
df = pd.read_csv(data, header=None)

# %%
df.shape
# Out:
# (401, 11)

# %%
df.head()
# Out:
#       0          1       2            3           4      5          6    7   \
# 0  Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age
# 1    9.5        138      73           11         276    120        Bad   42
# 2  11.22        111      48           16         260     83       Good   65
# 3  10.06        113      35           10         269     80     Medium   59
# 4    7.4        117     100            4         466     97     Medium   55
#
#           8      9    10
# 0  Education  Urban   US
# 1         17    Yes  Yes
# 2         10    Yes  Yes
# 3         12    Yes  Yes
# 4         14    Yes  Yes

# %%
col_names = ['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'ShelveLoc', 'Age', 'Education', 'Urban', 'US']

# %%
df.columns = col_names

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0  Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age
# 1    9.5        138      73           11         276    120        Bad   42
# 2  11.22        111      48           16         260     83       Good   65
# 3  10.06        113      35           10         269     80     Medium   59
# 4    7.4        117     100            4         466     97     Medium   55
#
#    Education  Urban   US
# 0  Education  Urban   US
# 1         17    Yes  Yes
# 2         10    Yes  Yes
# 3         12    Yes  Yes
# 4         14    Yes  Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        401 non-null    object
#  1   CompPrice    401 non-null    object
#  2   Income       401 non-null    object
#  3   Advertising  401 non-null    object
#  4   Population   401 non-null    object
#  5   Price        401 non-null    object
#  6   ShelveLoc    401 non-null    object
#  7   Age          401 non-null    object
#  8   Education    401 non-null    object
#  9   Urban        401 non-null    object
#  10  US           401 non-null    object
# dtypes: object(11)
# memory usage: 34.6+ KB

# %%
col_names = ['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'ShelveLoc', 'Age', 'Education', 'Urban', 'US']

# %%
for col in col_names:
    
    print(df[col].value_counts())
# Out:
# 7.8     4
# 8.77    3
# 9.32    3
# 6.88    3
# 6.53    3
#        ..
# 2.86    1
# 7.7     1
# 5.71    1
# 5.25    1
# 5.56    1
# Name: Sales, Length: 337, dtype: int64
# 121    16
# 122    14
# 131    14
# 123    13
# 132    12
#        ..
# 97      1
# 77      1
# 94      1
# 85      1
# 161     1
# Name: CompPrice, Length: 74, dtype: int64
# 69        11
# 42        10
# 100        8
# 32         8
# 84         7
#           ..
# Income     1
# 55         1
# 95         1
# 112        1
# 114        1
# Name: Income, Length: 99, dtype: int64
# 0              144
# 10              25
# 11              22
# 13              20
# 5               19
# 12              16
# 7               16
# 3               14
# 15              12
# 4               12
# 14              11
# 8               11
# 16              11
# 9               10
# 2                9
# 1                8
# 19               8
# 6                7
# 18               6
# 17               6
# 20               4
# ...

# %%
df['US'].value_counts()
# Out:
# Yes    258
# No     142
# US       1
# Name: US, dtype: int64

# %%
df.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
X = df.drop(['US'], axis=1)

y = df['US']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((268, 10), (133, 10))

# %%
X_train.dtypes
# Out:
# Sales          object
# CompPrice      object
# Income         object
# Advertising    object
# Population     object
# Price          object
# ShelveLoc      object
# Age            object
# Education      object
# Urban          object
# dtype: object

# %%
X_train.head()
# Out:
#     Sales CompPrice Income Advertising Population Price ShelveLoc Age  \
# 177  5.61       138    107           9        480   154    Medium  47
# 119  7.57       112     88           2        243    99    Medium  62
# 195  7.23       112     98          18        481   128    Medium  45
# 341   7.5       140     29           0        105    91       Bad  43
# 266  5.31       130     35          10        402   129       Bad  39
#
#     Education Urban
# 177        11    No
# 119        11   Yes
# 195        11   Yes
# 341        16   Yes
# 266        17   Yes

# %%
import category_encoders as ce

# %%
encoder = ce.OrdinalEncoder(cols=['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'ShelveLoc', 'Age', 'Education', 'Urban', 'US'])

# %%
encoder = ce.OrdinalEncoder(cols=['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'ShelveLoc', 'Age', 'Education', 'Urban', 'US'])

# %%
X_train.head()
# Out:
#     Sales CompPrice Income Advertising Population Price ShelveLoc Age  \
# 177  5.61       138    107           9        480   154    Medium  47
# 119  7.57       112     88           2        243    99    Medium  62
# 195  7.23       112     98          18        481   128    Medium  45
# 341   7.5       140     29           0        105    91       Bad  43
# 266  5.31       130     35          10        402   129       Bad  39
#
#     Education Urban
# 177        11    No
# 119        11   Yes
# 195        11   Yes
# 341        16   Yes
# 266        17   Yes

# %%
X_test.head()
# Out:
#     Sales CompPrice Income Advertising Population Price ShelveLoc Age  \
# 285  6.97       106     46          11        414    96       Bad  79
# 281  2.86       121     86          10        496   145       Bad  51
# 33    6.2       107     32          12        236   137      Good  64
# 211  4.36       125     41           2        357   123       Bad  47
# 93   4.53       114    113           0         97   125    Medium  29
#
#     Education Urban
# 285        17    No
# 281        10   Yes
# 33         10    No
# 211        14    No
# 93         12   Yes

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)
